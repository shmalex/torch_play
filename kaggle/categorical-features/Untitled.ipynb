# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
FILE='train'

# %%
df = pd.read_csv(f'./input/{FILE}.csv')

# %%
df.ord_2
# Out:
# 0         Boiling Hot
# 1                Cold
# 2                Warm
# 3                 Hot
# 4            Lava Hot
#              ...
# 399995           Warm
# 399996            NaN
# 399997    Boiling Hot
# 399998       Lava Hot
# 399999       Freezing
# Name: ord_2, Length: 400000, dtype: object

# %%
af = pd.read_csv('./input/animals.csv', sep='\t')
af = af.set_index('animal')
af_columns = af.columns
af = af.to_dict('index')

# %%
af = defaultdict(str, af)
af[np.nan] = {'water': 'n', 'home': 'n', 'fure': 'n', 'mass': 7.0}
af
# Out:
# defaultdict(str,
#             {'Axolotl': {'water': 'y', 'home': 'n', 'fure': 'n', 'mass': 1.0},
#              'Cat': {'water': 'n', 'home': 'y', 'fure': 'y', 'mass': 20.0},
#              'Dog': {'water': 'n', 'home': 'y', 'fure': 'y', 'mass': 40.0},
#              'Hamster': {'water': 'n', 'home': 'y', 'fure': 'y', 'mass': 0.1},
#              'Lion': {'water': 'n', 'home': 'n', 'fure': 'y', 'mass': 200.0},
#              'Snake': {'water': 'n', 'home': 'n', 'fure': 'n', 'mass': 7.0},
#              nan: {'water': 'n', 'home': 'n', 'fure': 'n', 'mass': 7.0}})

# %%
af_columns
# Out:
# Index(['water', 'home', 'fure', 'mass'], dtype='object')

# %%
df[['animal_' + afc for afc in af_columns]]=df.apply(lambda x: pd.Series(af[x['nom_2']]), axis=1)[af_columns]

# %%
df.head()
# Out:
#        id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0    nom_1    nom_2  \
# 0  600000    0.0    0.0    0.0     F     Y  Blue  Polygon  Axolotl
# 1  600001    0.0    0.0    0.0     F     Y   Red   Circle     Lion
# 2  600002    0.0    0.0    0.0     F     Y  Blue   Circle  Axolotl
# 3  600003    1.0    0.0    0.0     F     N   Red  Polygon  Axolotl
# 4  600004    0.0    0.0    1.0     F     Y   Red   Circle      NaN
#
#         nom_3  ...        ord_2 ord_3 ord_4 ord_5  day month  animal_water  \
# 0     Finland  ...  Boiling Hot     f     U    oU  3.0   9.0             y
# 1      Russia  ...         Cold     n     N   NaN  2.0   8.0             n
# 2      Russia  ...         Warm     i     N    DN  2.0   6.0             y
# 3  Costa Rica  ...          Hot     m     B    AG  1.0   6.0             y
# 4     Finland  ...     Lava Hot     o     J    DT  3.0   3.0             n
#
#   animal_home animal_fure animal_mass
# 0           n           n         1.0
# ...

# %%
cf = pd.read_csv('input/countries.csv', sep='\t')
country_missing = cf.mean().to_dict()
cf = cf.set_index('country')
cf_columns = cf.columns
cf = cf.to_dict('index')
cf
# Out:
# {'Russia': {'population': 146171015,
#   'gdp': 4328000000000,
#   'gdp per capita': 29485,
#   'timzone': 10.0,
#   'water': 0.13,
#   'w': 37.37,
#   'n': 55.45},
#  'Canada': {'population': 38048738,
#   'gdp': 1979000000000,
#   'gdp per capita': 51713,
#   'timzone': 5.5,
#   'water': 11.76,
#   'w': 75.4,
#   'n': 45.24},
#  'Finland': {'population': 5536146,
#   'gdp': 257000000000,
#   'gdp per capita': 49334,
#   'timzone': 2.0,
#   'water': 9.71,
#   'w': 24.56,
#   'n': 60.1},
#  'Costa Rica': {'population': 5094118,
#   'gdp': 95791000000,
#   'gdp per capita': 18651,
#   'timzone': 1.0,
#   'water': 1.05,
#   'w': 84.5,
#   'n': 9.56},
#  'China': {'population': 1412000000000,
#   'gdp': 26660000000000,
#   'gdp per capita': 18931,
#   'timzone': 1.0,
#   'water': 2.8,
#   'w': 116.23,
#   'n': 39.55},
#  'India': {'population': 1352642280,
#   'gdp': 10207000000000,
#   'gdp per capita': 7333,
#   'timzone': 1.0,
#   'water': 9.6,
#   'w': 77.12,
#   'n': 28.36}}

# %%
cf_columns
# Out:
# Index(['population', 'gdp', 'gdp per capita', 'timzone', 'water', 'w', 'n'], dtype='object')

# %%
country_missing
# Out:
# {'population': 235591248716.16666,
#  'gdp': 7254465166666.667,
#  'gdp per capita': 29241.166666666668,
#  'timzone': 3.4166666666666665,
#  'water': 5.841666666666668,
#  'w': 69.19666666666667,
#  'n': 39.71}

# %%
cf = defaultdict(str, cf)
cf[np.nan] = country_missing
cf
# Out:
# defaultdict(str,
#             {'Russia': {'population': 146171015,
#               'gdp': 4328000000000,
#               'gdp per capita': 29485,
#               'timzone': 10.0,
#               'water': 0.13,
#               'w': 37.37,
#               'n': 55.45},
#              'Canada': {'population': 38048738,
#               'gdp': 1979000000000,
#               'gdp per capita': 51713,
#               'timzone': 5.5,
#               'water': 11.76,
#               'w': 75.4,
#               'n': 45.24},
#              'Finland': {'population': 5536146,
#               'gdp': 257000000000,
#               'gdp per capita': 49334,
#               'timzone': 2.0,
#               'water': 9.71,
#               'w': 24.56,
#               'n': 60.1},
#              'Costa Rica': {'population': 5094118,
#               'gdp': 95791000000,
#               'gdp per capita': 18651,
#               'timzone': 1.0,
#               'water': 1.05,
#               'w': 84.5,
# ...

# %%
df[['country_'+cfc for cfc in cf_columns]]=df.apply(lambda x: pd.Series(cf[x['nom_3']]), axis=1)[cf_columns]

# %%
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0       600000    0.0    0.0    0.0     F     Y  Blue    Polygon  Axolotl
# 1       600001    0.0    0.0    0.0     F     Y   Red     Circle     Lion
# 2       600002    0.0    0.0    0.0     F     Y  Blue     Circle  Axolotl
# 3       600003    1.0    0.0    0.0     F     N   Red    Polygon  Axolotl
# 4       600004    0.0    0.0    1.0     F     Y   Red     Circle      NaN
# ...        ...    ...    ...    ...   ...   ...   ...        ...      ...
# 399995  999995    0.0    0.0    1.0     T     N   Red  Trapezoid  Axolotl
# 399996  999996    0.0    0.0    0.0     F     N   Red    Polygon      Dog
# 399997  999997    0.0    0.0    1.0     T     N   Red   Triangle  Hamster
# 399998  999998    0.0    0.0    0.0     F     Y   Red     Circle      Dog
# 399999  999999    0.0    0.0    1.0     F     N  Blue     Circle     Lion
#
#              nom_3  ... animal_home animal_fure animal_mass  \
# ...

# %%
hf = pd.read_csv('input/heat.csv', sep='\t')
heat_missing = hf.mean().to_dict()
hf = hf.set_index('heat')
hf_columns = hf.columns
hf = hf.to_dict('index')
hf,heat_missing
# Out:
# ({'Freezing': {'rank': 1},
#   'Cold': {'rank': 2},
#   'Warm': {'rank': 3},
#   'Hot': {'rank': 4},
#   'Boiling Hot': {'rank': 5},
#   'Lava Hot': {'rank': 6}},
#  {'rank': 3.5})

# %%
hf = defaultdict(str, hf)
hf[np.nan] = heat_missing
hf
# Out:
# defaultdict(str,
#             {'Freezing': {'rank': 1},
#              'Cold': {'rank': 2},
#              'Warm': {'rank': 3},
#              'Hot': {'rank': 4},
#              'Boiling Hot': {'rank': 5},
#              'Lava Hot': {'rank': 6},
#              nan: {'rank': 3.5}})

# %%
df[['heat_'+hfc for hfc in hf_columns]]=df.apply(lambda x: pd.Series(hf[x['ord_2']]), axis=1)[hf_columns]

# %%
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0       600000    0.0    0.0    0.0     F     Y  Blue    Polygon  Axolotl
# 1       600001    0.0    0.0    0.0     F     Y   Red     Circle     Lion
# 2       600002    0.0    0.0    0.0     F     Y  Blue     Circle  Axolotl
# 3       600003    1.0    0.0    0.0     F     N   Red    Polygon  Axolotl
# 4       600004    0.0    0.0    1.0     F     Y   Red     Circle      NaN
# ...        ...    ...    ...    ...   ...   ...   ...        ...      ...
# 399995  999995    0.0    0.0    1.0     T     N   Red  Trapezoid  Axolotl
# 399996  999996    0.0    0.0    0.0     F     N   Red    Polygon      Dog
# 399997  999997    0.0    0.0    1.0     T     N   Red   Triangle  Hamster
# 399998  999998    0.0    0.0    0.0     F     Y   Red     Circle      Dog
# 399999  999999    0.0    0.0    1.0     F     N  Blue     Circle     Lion
#
#              nom_3  ... animal_fure animal_mass country_population  \
# ...

# %%
inf = pd.read_csv('input/instruments.csv', sep='\t')
inst_missing = inf.mean().to_dict()
inst_missing = {'mass':2,'strings': 'n',
   'electric': 'n',
   'blow': 'y',
   'keys': 'n'}
inf = inf.set_index('instrument')
inf_columns = inf.columns
inf = inf.to_dict('index')
inf,inst_missing
# Out:
# ({'Piano': {'mass': 200,
#    'strings': 'y',
#    'electric': 'n',
#    'blow': 'n',
#    'keys': 'y'},
#   'Oboe': {'mass': 3,
#    'strings': 'n',
#    'electric': 'n',
#    'blow': 'y',
#    'keys': 'n'},
#   'Bassoon': {'mass': 10,
#    'strings': 'n',
#    'electric': 'n',
#    'blow': 'y',
#    'keys': 'n'},
#   'Theremin': {'mass': 2,
#    'strings': 'n',
#    'electric': 'y',
#    'blow': 'n',
#    'keys': 'y'}},
#  {'mass': 2, 'strings': 'n', 'electric': 'n', 'blow': 'y', 'keys': 'n'})

# %%
inf = defaultdict(str, inf)
inf[np.nan] = inst_missing
inf
# Out:
# defaultdict(str,
#             {'Piano': {'mass': 200,
#               'strings': 'y',
#               'electric': 'n',
#               'blow': 'n',
#               'keys': 'y'},
#              'Oboe': {'mass': 3,
#               'strings': 'n',
#               'electric': 'n',
#               'blow': 'y',
#               'keys': 'n'},
#              'Bassoon': {'mass': 10,
#               'strings': 'n',
#               'electric': 'n',
#               'blow': 'y',
#               'keys': 'n'},
#              'Theremin': {'mass': 2,
#               'strings': 'n',
#               'electric': 'y',
#               'blow': 'n',
#               'keys': 'y'},
#              nan: {'mass': 2,
#               'strings': 'n',
#               'electric': 'n',
#               'blow': 'y',
#               'keys': 'n'}})

# %%
df[['inst_'+inc for inc in inf_columns]]=df.apply(lambda x: pd.Series(inf[x['nom_4']]), axis=1)[inf_columns]

# %%
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0       600000    0.0    0.0    0.0     F     Y  Blue    Polygon  Axolotl
# 1       600001    0.0    0.0    0.0     F     Y   Red     Circle     Lion
# 2       600002    0.0    0.0    0.0     F     Y  Blue     Circle  Axolotl
# 3       600003    1.0    0.0    0.0     F     N   Red    Polygon  Axolotl
# 4       600004    0.0    0.0    1.0     F     Y   Red     Circle      NaN
# ...        ...    ...    ...    ...   ...   ...   ...        ...      ...
# 399995  999995    0.0    0.0    1.0     T     N   Red  Trapezoid  Axolotl
# 399996  999996    0.0    0.0    0.0     F     N   Red    Polygon      Dog
# 399997  999997    0.0    0.0    1.0     T     N   Red   Triangle  Hamster
# 399998  999998    0.0    0.0    0.0     F     Y   Red     Circle      Dog
# 399999  999999    0.0    0.0    1.0     F     N  Blue     Circle     Lion
#
#              nom_3  ... country_timzone country_water  country_w country_n  \
# ...

# %%
rf = pd.read_csv('input/rank.csv', sep='\t')
rank_missing = rf.mean().to_dict()
rf = rf.set_index('title')
rf_columns = rf.columns
rf = rf.to_dict('index')
rf,rank_missing
# Out:
# ({'Grandmaster': {'rank': 5},
#   'Expert': {'rank': 4},
#   'Master': {'rank': 3},
#   'Contributor': {'rank': 2},
#   'Novice': {'rank': 1}},
#  {'rank': 3.0})

# %%
rf = defaultdict(str, rf)
rf[np.nan] = rank_missing
rf
# Out:
# defaultdict(str,
#             {'Grandmaster': {'rank': 5},
#              'Expert': {'rank': 4},
#              'Master': {'rank': 3},
#              'Contributor': {'rank': 2},
#              'Novice': {'rank': 1},
#              nan: {'rank': 3.0}})

# %%
df[['rank_'+rfc for rfc in rf_columns]]=df.apply(lambda x: pd.Series(rf[x['ord_1']]), axis=1)[rf_columns]

# %%
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0       600000    0.0    0.0    0.0     F     Y  Blue    Polygon  Axolotl
# 1       600001    0.0    0.0    0.0     F     Y   Red     Circle     Lion
# 2       600002    0.0    0.0    0.0     F     Y  Blue     Circle  Axolotl
# 3       600003    1.0    0.0    0.0     F     N   Red    Polygon  Axolotl
# 4       600004    0.0    0.0    1.0     F     Y   Red     Circle      NaN
# ...        ...    ...    ...    ...   ...   ...   ...        ...      ...
# 399995  999995    0.0    0.0    1.0     T     N   Red  Trapezoid  Axolotl
# 399996  999996    0.0    0.0    0.0     F     N   Red    Polygon      Dog
# 399997  999997    0.0    0.0    1.0     T     N   Red   Triangle  Hamster
# 399998  999998    0.0    0.0    0.0     F     Y   Red     Circle      Dog
# 399999  999999    0.0    0.0    1.0     F     N  Blue     Circle     Lion
#
#              nom_3  ... country_water  country_w country_n heat_rank  \
# ...

# %%
FILE
# Out:
# 'test'

# %%
df.to_csv(f'./input/{FILE}_expanded.csv', sep='\t', index=False)

# %%
df.columns
# Out:
# Index(['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'nom_0', 'nom_1',
#        'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9',
#        'ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#        'animal_water', 'animal_home', 'animal_fure', 'animal_mass',
#        'country_population', 'country_gdp', 'country_gdp per capita',
#        'country_timzone', 'country_water', 'country_w', 'country_n',
#        'heat_rank', 'inst_mass', 'inst_strings', 'inst_electric', 'inst_blow',
#        'inst_keys', 'rank_rank'],
#       dtype='object')

# %%
df = pd.read_csv('./input/train_expanded.csv')
df.columns = [cl.replace(' ','_') for cl in df.columns]

# %%
df.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# 0   0    0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1   1    1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2   2    0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3   3    NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4   4    0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#    ... country_water  country_w country_n heat_rank inst_mass inst_strings  \
# 0  ...      0.130000  37.370000     55.45       4.0        10            n
# 1  ...      5.841667  69.196667     39.71       3.0         2            n
# 2  ...     11.760000  75.400000     45.24       1.0        10            n
# 3  ...      9.710000  24.560000     60.10       6.0         2            n
# 4  ...      1.050000  84.500000      9.56       2.0         2            n
#
#    inst_electric inst_blow inst_keys rank_rank
# ...

# %%
df.to_csv('./input/train_expanded.csv', index=False)

# %%
df.columns
# Out:
# Index(['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'nom_0', 'nom_1',
#        'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9',
#        'ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#        'animal_water', 'animal_home', 'animal_fure', 'animal_mass',
#        'country_population', 'country_gdp', 'country_gdp per capita',
#        'country_timzone', 'country_water', 'country_w', 'country_n',
#        'heat_rank', 'inst_mass', 'inst_strings', 'inst_electric', 'inst_blow',
#        'inst_keys', 'rank_rank'],
#       dtype='object')

# %%
df.head()
# Out:
#        id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0    nom_1    nom_2  \
# 0  600000    0.0    0.0    0.0     F     Y  Blue  Polygon  Axolotl
# 1  600001    0.0    0.0    0.0     F     Y   Red   Circle     Lion
# 2  600002    0.0    0.0    0.0     F     Y  Blue   Circle  Axolotl
# 3  600003    1.0    0.0    0.0     F     N   Red  Polygon  Axolotl
# 4  600004    0.0    0.0    1.0     F     Y   Red   Circle      NaN
#
#         nom_3  ... country_water country_w country_n heat_rank inst_mass  \
# 0     Finland  ...          9.71     24.56     60.10       5.0       200
# 1      Russia  ...          0.13     37.37     55.45       2.0        10
# 2      Russia  ...          0.13     37.37     55.45       3.0         2
# 3  Costa Rica  ...          1.05     84.50      9.56       4.0        10
# 4     Finland  ...          9.71     24.56     60.10       6.0         2
#
#   inst_strings  inst_electric inst_blow inst_keys rank_rank
# 0            y              n         n         y       1.0
# ...
